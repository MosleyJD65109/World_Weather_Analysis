# %%
# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# kapaa us
# qaanaaq gl
# honiara sb
# rawson ar
# zhuhai cn
# seoul kr
# albany au
# karpathos gr
# rikitea pf
# matagami ca
# cherskiy ru
# mar del plata ar
# hasaki jp
# lawrenceburg us
# codrington ag
# mataura pf
# rikitea pf
# tiksi ru
# vaini to
# hobart au
# hobart au
# illoqqortoormiut gl
# kyren ru
# havoysund no
# dingle ie
# qaanaaq gl
# chuy uy
# hermanus za
# vestmannaeyjar is
# new norfolk au
# kamwenge ug
# port lincoln au
# placerville us
# sorland no
# tecpan mx
# kariba zw
# manokwari id
# clyde river ca
# belushya guba ru
# waddan ly
# maniitsoq gl
# zavetnoye ru
# kanniyakumari in
# ushuaia ar
# rikitea pf
# kotovo ru
# illoqqortoormiut gl
# pousat kh
# busselton au
# bethel us
# waddan ly
# muhos fi
# hobbs us
# atuona pf
# hilo us
# butaritari ki
# hilo us
# kodiak us
# rochegda ru
# butaritari ki
# busselton au
# bredasdorp za
# oussouye sn
# point pedro lk
# kita ml
# busselton au
# punta arenas cl
# jamestown sh
# thai binh vn
# sapouy bf
# mataura pf
# taolanaro mg
# ushuaia ar
# vaini to
# belushya guba ru
# cape town za
# ushuaia ar
# ambanja mg
# hilo us
# abu samrah qa
# belaya gora ru
# olafsvik is
# bousse bf
# port alfred za
# teknaf bd
# kenora ca
# yellowknife ca
# bambous virieux mu
# tasiilaq gl
# isangel vu
# seredka ru
# bafq ir
# kaitangata nz
# naze jp
# amapa br
# tuatapere nz
# avarua ck
# faanui pf
# bluff nz
# taolanaro mg
# torbay ca
# digby ca
# huambo ao
# kruisfontein za
# axim gh
# waingapu id
# airai pw
# ust-ilimsk ru
# marcona pe
# college us
# yellowknife ca
# carnarvon au
# los llanos de aridane es
# potsdam us
# guerrero negro mx
# georgetown sh
# new norfolk au
# mayo ca
# port alfred za
# saldanha za
# atuona pf
# chokurdakh ru
# taolanaro mg
# mataura pf
# vardo no
# albany au
# saskylakh ru
# rikitea pf
# busselton au
# mar del plata ar
# hobart au
# busselton au
# ushuaia ar
# ushuaia ar
# nikolskoye ru
# ribeira grande pt
# zabid ye
# kavaratti in
# barrow us
# punta arenas cl
# avarua ck
# punta arenas cl
# albany au
# hermanus za
# hainburg at
# cape town za
# sao filipe cv
# cockburn town bs
# anadyr ru
# albany au
# rikitea pf
# bonavista ca
# padang id
# mataura pf
# bredasdorp za
# ushuaia ar
# raudeberg no
# belmonte br
# pisco pe
# busselton au
# narsaq gl
# katangli ru
# gambiran id
# hambantota lk
# gagret in
# nikolskoye ru
# khatanga ru
# hilo us
# dikson ru
# hobart au
# tautira pf
# bourail nc
# jamestown sh
# busselton au
# vestmanna fo
# cape town za
# rikitea pf
# hammerfest no
# hermanus za
# mayo ca
# stephenville us
# mahebourg mu
# sibu my
# dzhusaly kz
# attawapiskat ca
# katsuura jp
# dubbo au
# tsihombe mg
# dujuma so
# santa isabel do rio negro br
# bluff nz
# iralaya hn
# tevriz ru
# yar-sale ru
# hihifo to
# nikolskoye ru
# hofn is
# mount isa au
# coquimbo cl
# talnakh ru
# bluff nz
# omboue ga
# sechura pe
# jamestown sh
# hilo us
# verkhoyansk ru
# castro cl
# qaanaaq gl
# muros es
# beloha mg
# new norfolk au
# dikson ru
# lasa cn
# dikson ru
# geraldton au
# shimoda jp
# lakatoro vu
# ushuaia ar
# amderma ru
# port alfred za
# avarua ck
# vaini to
# ushuaia ar
# puerto ayora ec
# shingu jp
# port hardy ca
# barrow us
# kununurra au
# cururupu br
# mataura pf
# bluff nz
# kavaratti in
# east london za
# arraial do cabo br
# kaitangata nz
# vila velha br
# saint george bm
# puerto ayora ec
# busselton au
# hermanus za
# hobart au
# butaritari ki
# mataura pf
# hithadhoo mv
# halalo wf
# tiksi ru
# sao filipe cv
# bilibino ru
# linshu cn
# bluff nz
# east london za
# shakawe bw
# busselton au
# hermanus za
# tiksi ru
# punta arenas cl
# kapaa us
# hobart au
# busselton au
# ganzhou cn
# atkinson dm
# aranos na
# east london za
# asau tv
# barrow us
# new norfolk au
# ushuaia ar
# nizhneyansk ru
# provideniya ru
# hilo us
# albany au
# alta floresta br
# tsihombe mg
# esperance au
# vaini to
# kumluca tr
# lebu cl
# altona ca
# lebu cl
# bourail nc
# punta arenas cl
# coquimbo cl
# port alfred za
# rio claro br
# ilulissat gl
# kaitangata nz
# houma us
# vaitupu wf
# de-kastri ru
# palabuhanratu id
# miraflores co
# mar del plata ar
# kodiak us
# rundu na
# kumluca tr
# mar del plata ar
# ushuaia ar
# saleaula ws
# teya ru
# tasiilaq gl
# san quintin mx
# tres lagoas br
# rikitea pf
# barrow us
# mar del plata ar
# lookan ph
# mar del plata ar
# dikson ru
# cap malheureux mu
# rikitea pf
# rampur hat in
# saint george bm
# laguna br
# evensk ru
# oranjemund na
# jamestown sh
# rudbar af
# jamestown sh
# atuona pf
# clyde river ca
# torbay ca
# langenburg ca
# new norfolk au
# bambous virieux mu
# balkhash kz
# new norfolk au
# norman wells ca
# ust-nera ru
# mount gambier au
# atuona pf
# rehoboth na
# pedreiras br
# saleaula ws
# rikitea pf
# ritchie za
# atuona pf
# rikitea pf
# castro cl
# ushuaia ar
# rikitea pf
# cape town za
# soyo ao
# saskylakh ru
# stonewall ca
# rikitea pf
# san cristobal ec
# punta arenas cl
# alofi nu
# mar del plata ar
# thompson ca
# san luis cu
# illoqqortoormiut gl
# kilmaurs gb
# jawala mukhi in
# tuy hoa vn
# vaini to
# olafsvik is
# velyka oleksandrivka ua
# butaritari ki
# bluff nz
# yomitan jp
# yilan cn
# hwange zw
# henties bay na
# busselton au
# illoqqortoormiut gl
# ushuaia ar
# castro cl
# vaitupu wf
# busselton au
# tuktoyaktuk ca
# new norfolk au
# sorland no
# busselton au
# sitka us
# ribeira grande pt
# aksu cn
# chaplynka ua
# albany au
# agutaya ph
# rikitea pf
# ye mm
# cape town za
# rikitea pf
# tongliao cn
# mount gambier au
# avarua ck
# nizhneyansk ru
# negele et
# bluff nz
# sosnovo-ozerskoye ru
# tsihombe mg
# bobo dioulasso bf
# san patricio mx
# east london za
# east london za
# sinop tr
# labuhan id
# atuona pf
# rikitea pf
# leninsk ru
# jamestown sh
# tuktoyaktuk ca
# rikitea pf
# castro cl
# thompson ca
# sao filipe cv
# vestmannaeyjar is
# lillooet ca
# bethel us
# cape town za
# castro cl
# ahipara nz
# saint-philippe re
# ribeira grande pt
# sunndalsora no
# toro es
# sawtell au
# pisco pe
# tazovskiy ru
# mar del plata ar
# dudinka ru
# talnakh ru
# qaqortoq gl
# bubaque gw
# sandwick gb
# punta arenas cl
# hobart au
# ponta do sol cv
# port alfred za
# illoqqortoormiut gl
# kijang id
# broome au
# sorland no
# nanortalik gl
# esperance au
# saleaula ws
# georgetown sh
# upernavik gl
# castro cl
# bengkulu id
# barentsburg sj
# tucuma br
# saint anthony ca
# qaanaaq gl
# bonthe sl
# carnarvon au
# yulara au
# clyde river ca
# bataipora br
# awjilah ly
# te anau nz
# inzer ru
# khasan ru
# egvekinot ru
# avera pf
# srednekolymsk ru
# punta arenas cl
# matara lk
# punta arenas cl
# faanui pf
# atuona pf
# deoli in
# mataura pf
# tiarei pf
# ushuaia ar
# cherskiy ru
# mataura pf
# buala sb
# kapaa us
# honiara sb
# savalou bj
# rikitea pf
# hermanus za
# katunki ru
# ushtobe kz
# winona us
# rikitea pf
# macaboboni ph
# bluff nz
# darab ir
# anadyr ru
# arraial do cabo br
# cape town za
# kutum sd
# punta arenas cl
# butaritari ki
# tiksi ru
# goderich sl
# bluff nz
# kishi ng
# busselton au
# ushuaia ar
# cape town za
# sur om
# lasa cn
# bluff nz
# port-gentil ga
# bathsheba bb
# vaini to
# vaitupu wf
# presidencia roque saenz pena ar
# phuntsholing bt
# margate za
# atuona pf
# provideniya ru
# bredasdorp za
# portland au
# butaritari ki
# los llanos de aridane es
# castro cl
# hilo us
# nemuro jp
# ushuaia ar
# san andres co
# bluff nz
# hilo us
# pacific grove us
# hobart au
# phrai bung th
# puerto ayora ec
# nouadhibou mr
# novopokrovka ru
# albany au
# aklavik ca
# rikitea pf
# kaitangata nz
# oksfjord no
# new norfolk au
# turukhansk ru
# hilo us
# egvekinot ru
# tomatlan mx
# vaini to
# saint-philippe re
# acajutla sv
# kavaratti in
# rikitea pf
# cape town za
# ahuimanu us
# ponta delgada pt
# husavik is
# vaini to
# qaanaaq gl
# entre rios bo
# clyde river ca
# sandpoint us
# barentu er
# qaanaaq gl
# funadhoo mv
# nizhneyansk ru
# busselton au
# souillac mu
# atlantic city us
# jamestown sh
# kargil in
# tacoronte es
# nizhniy odes ru
# barentsburg sj
# itoigawa jp
# mogadishu so
# kruisfontein za
# alta floresta br
# constitucion mx
# vaini to
# azimur ma
# quthing ls
# filadelfia py
# punta arenas cl
# willowmore za
# jamestown sh
# tiksi ru
# ribeira grande pt
# makakilo city us
# qingdao cn
# luang prabang la
# mackay au
# sinnamary gf
# aswan eg
# ukiah us
# karema tz
# sundsvall se
# vanersborg se
# galveston us
# portland au
# saint george bm
# busselton au
# kodiak us
# saint-philippe re
# victoria sc
# sao filipe cv
# ahipara nz
# hilo us
# tasiilaq gl
# bredasdorp za
# port elizabeth za
# hermanus za
# mataura pf
# carnarvon au
# cape town za
# new norfolk au
# tuktoyaktuk ca
# puerto ayora ec
# saint george bm
# avarua ck
# punta arenas cl
# kyshtovka ru
# paradwip in
# bethel us
# vaini to
# barentsburg sj
# zhanaozen kz
# umm lajj sa
# samusu ws
# bulgan mn
# anadyr ru
# tillabery ne
# busselton au
# punta arenas cl
# punta arenas cl
# tumannyy ru
# buchanan lr
# bilibino ru
# kavieng pg
# hobart au
# malters ch
# faanui pf
# qaanaaq gl
# barrow us
# jamestown sh
# butaritari ki
# kapaa us
# hermanus za
# belushya guba ru
# norman wells ca
# butembo cd
# honiara sb
# mys shmidta ru
# ushuaia ar
# samusu ws
# plettenberg bay za
# mataura pf
# udachnyy ru
# port alfred za
# chapais ca
# mys shmidta ru
# broome au
# sao felix do xingu br
# dikson ru
# airai pw
# lebu cl
# hermanus za
# saint-philippe re
# cape town za
# bluff nz
# sentyabrskiy ru
# deputatskiy ru
# cape town za
# king city us
# aykhal ru
# bambous virieux mu
# khatanga ru
# puerto ayora ec
# sitka us
# avarua ck
# thompson ca
# albany au
# busselton au
# grindavik is
# terrace ca
# arteaga mx
# hithadhoo mv
# bethel us
# constitucion mx
# albany au
# lavrentiya ru
# rikitea pf
# iralaya hn
# bodaybo ru
# lago da pedra br
# mataura pf
# cape town za
# geraldton au
# kristiansund no
# avarua ck
# ribeira grande pt
# grindavik is
# los llanos de aridane es
# bambous virieux mu
# ponta do sol cv
# puerto ayora ec
# vao nc
# novobirilyussy ru
# qaanaaq gl
# veshkayma ru
# ilulissat gl
# auki sb
# tasiilaq gl
# martil ma
# punta arenas cl
# poum nc
# ngukurr au
# shache cn
# phuket th
# ostrovnoy ru
# bredasdorp za
# albany au
# arraial do cabo br
# vestmanna fo
# taolanaro mg
# port alfred za
# punta arenas cl
# mys shmidta ru
# belushya guba ru
# norman wells ca
# gizo sb
# merauke id
# eureka us
# albany au
# qaanaaq gl
# geraldton au
# port hedland au
# castro cl
# mackenzie ca
# hermanus za
# dzhusaly kz
# mosquera co
# luanda ao
# karwar in
# sola vu
# namibe ao
# sciacca it
# busselton au
# castro cl
# mahajanga mg
# omsukchan ru
# ponta do sol cv
# mataura pf
# rikitea pf
# hefei cn
# korla cn
# albany au
# pucallpa pe
# mahebourg mu
# taoudenni ml
# dikson ru
# ahipara nz
# camocim br
# rocha uy
# lasa cn
# atuona pf
# atuona pf
# avarua ck
# avarua ck
# avarua ck
# lac-megantic ca
# puerto ayora ec
# atuona pf
# hobart au
# manta ec
# busselton au
# sentyabrskiy ru
# asau tv
# provideniya ru
# hilo us
# mananjary mg
# busselton au
# bambous virieux mu
# jamestown sh
# cape town za
# vostok ru
# torbay ca
# attawapiskat ca
# port hardy ca
# yirol sd
# yerbogachen ru
# tidore id
# tautira pf
# hithadhoo mv
# hilo us
# lebu cl
# aykhal ru
# puerto ayora ec
# sitka us
# ushuaia ar
# thompson ca
# arraial do cabo br
# rawson ar
# rikitea pf
# hermanus za
# qasigiannguit gl
# puerto ayora ec
# vila franca do campo pt
# hobart au
# cape town za
# barcelos br
# lahaina us
# kaitangata nz
# ugoofaaru mv
# forquilhinha br
# dagana sn
# punta arenas cl
# kiama au
# jamestown sh
# pevek ru
# killarney ca
# hermanus za
# kilim ph
# punta arenas cl
# barrow us
# ukiah us
# nemuro jp
# half moon bay us
# saskylakh ru
# yokadouma cm
# rikitea pf
# ushuaia ar
# ribeira grande pt
# shenjiamen cn
# ylivieska fi
# berlevag no
# ipinda tz
# busselton au
# qaanaaq gl
# cherskiy ru
# clyde river ca
# jamestown sh
# beringovskiy ru
# busselton au
# barentsburg sj
# panguipulli cl
# kapaa us
# tuktoyaktuk ca
# mount gambier au
# jiutai cn
# bambous virieux mu
# mataura pf
# yei sd
# albany au
# lata sb
# busselton au
# punta arenas cl
# bredasdorp za
# jamestown sh
# ponta do sol cv
# hasaki jp
# muli mv
# oranjemund na
# cabedelo br
# nizhneyansk ru
# new baltimore us
# wanaka nz
# ushuaia ar
# tuy hoa vn
# mataura pf
# butaritari ki
# qaanaaq gl
# hermanus za
# yellowknife ca
# luderitz na
# hay river ca
# deputatskiy ru
# port alfred za
# tuktoyaktuk ca
# albany au
# taolanaro mg
# ushuaia ar
# liwonde mw
# aklavik ca
# charapan mx
# punta arenas cl
# puerto ayora ec
# qaanaaq gl
# nikolskoye ru
# attawapiskat ca
# cuenca es
# klaksvik fo
# kilindoni tz
# cape town za
# nikolskoye ru
# barawe so
# lebu cl
# bambous virieux mu
# funtua ng
# port blair in
# busselton au
# rikitea pf
# ekhabi ru
# grootfontein na
# jalingo ng
# hailar cn
# meulaboh id
# bredasdorp za
# vestmannaeyjar is
# tabou ci
# vaini to
# hobart au
# gamba ga
# hithadhoo mv
# butaritari ki
# tiksi ru
# tuktoyaktuk ca
# bengkulu id
# jiaohe cn
# hami cn
# carnarvon au
# tasiilaq gl
# thompson ca
# smithers ca
# illoqqortoormiut gl
# ushuaia ar
# hithadhoo mv
# punta arenas cl
# busselton au
# ushuaia ar
# tasiilaq gl
# lebu cl
# hualmay pe
# lavrentiya ru
# ushuaia ar
# anadyr ru
# torbay ca
# emba kz
# mar del plata ar
# saint-philippe re
# jamestown sh
# mar del plata ar
# puerto ayora ec
# kosh-agach ru
# rikitea pf
# clyde river ca
# cherskiy ru
# ushuaia ar
# komsomolskiy ru
# puerto ayora ec
# hilo us
# butaritari ki
# ahipara nz
# havelock us
# saskylakh ru
# rikitea pf
# cape town za
# cape town za
# longyearbyen sj
# batticaloa lk
# bambous virieux mu
# jamestown sh
# havoysund no
# qaanaaq gl
# jamestown sh
# lolua tv
# taolanaro mg
# yellowknife ca
# albany au
# bud no
# taungdwingyi mm
# maloshuyka ru
# hermanus za
# fortuna us
# enshi cn
# fortuna us
# urdzhar kz
# pinega ru
# ushuaia ar
# norman wells ca
# hermanus za
# ihosy mg
# werda bw
# dikson ru
# nerchinskiy zavod ru
# ushuaia ar
# geraldton au
# victoria sc
# cape town za
# hobart au
# jiddah sa
# jamestown sh
# chuy uy
# taolanaro mg
# kasongo-lunda cd
# lebu cl
# beckley us
# faanui pf
# oktyabrskiy ru
# vardo no
# katsuura jp
# petropavlovsk-kamchatskiy ru
# mataura pf
# chokurdakh ru
# punta arenas cl
# butaritari ki
# botwood ca
# mabaruma gy
# kapaa us
# ushuaia ar
# punta arenas cl
# longyearbyen sj
# taoudenni ml
# belaya gora ru
# wasilla us
# hithadhoo mv
# pevek ru
# barrow us
# wuhu cn
# maceio br
# cape town za
# busselton au
# batouri cm
# rawannawi ki
# hilton head island us
# choma zm
# bathsheba bb
# kavieng pg
# lekoni ga
# port elizabeth za
# punta arenas cl
# plettenberg bay za
# satipo pe
# cabanbanan ph
# albany au
# khandagayty ru
# illoqqortoormiut gl
# bethel us
# puerto ayora ec
# rocha uy
# punta arenas cl
# miechow pl
# sentyabrskiy ru
# murgab tm
# nouadhibou mr
# ko samui th
# yellowknife ca
# tsihombe mg
# punta arenas cl
# hilo us
# thap than th
# east london za
# nizhneyansk ru
# punta arenas cl
# bambous virieux mu
# we nc
# busselton au
# kandi bj
# qaqortoq gl
# castro cl
# pevek ru
# cape town za
# hithadhoo mv
# thompson ca
# vaini to
# burica pa
# upernavik gl
# port lincoln au
# tacna pe
# ushuaia ar
# victoria sc
# kodiak us
# upernavik gl
# ushuaia ar
# glasgow us
# hobart au
# uruguaiana br
# telemaco borba br
# livingstone zm
# punta arenas cl
# honningsvag no
# punta arenas cl
# tasiilaq gl
# atuona pf
# port elizabeth za
# wagar sd
# chuy uy
# traverse city us
# jamestown sh
# rikitea pf
# cherskiy ru
# shafter us
# vaini to
# albany au
# putai tw
# rikitea pf
# dauphin ca
# conceicao da barra br
# shimoda jp
# busselton au
# hermanus za
# yellowknife ca
# bredasdorp za
# vila franca do campo pt
# busselton au
# cape town za
# cotoca bo
# vaini to
# praia da vitoria pt
# salaga gh
# mataura pf
# ushuaia ar
# rikitea pf
# new norfolk au
# barentsburg sj
# magadan ru
# butaritari ki
# kiruna se
# hithadhoo mv
# ponta do sol cv
# albany au
# puquio pe
# illoqqortoormiut gl
# hilo us
# paamiut gl
# carnarvon au
# zhezkazgan kz
# fortuna us
# puno pe
# chokurdakh ru
# khatanga ru
# vila franca do campo pt
# port elizabeth za
# teya ru
# saint anthony ca
# hithadhoo mv
# erzin ru
# castro cl
# gamba ga
# bluff nz
# asosa et
# vaitupu wf
# rikitea pf
# cherskiy ru
# bengkulu id
# sao joao da barra br
# belushya guba ru
# ushuaia ar
# kaitangata nz
# siniscola it
# hobart au
# vardo no
# east london za
# sitka us
# mataura pf
# yellowknife ca
# ancud cl
# clyde river ca
# wasilla us
# qaqortoq gl
# koungou yt
# kemijarvi fi
# cape town za
# ribeira grande pt
# alice springs au
# samarai pg
# floro no
# pevek ru
# punta arenas cl
# santa cruz ph
# amderma ru
# havre-saint-pierre ca
# port elizabeth za
# bambous virieux mu
# hobart au
# vaini to
# rikitea pf
# codrington ag
# alofi nu
# klaksvik fo
# victoria sc
# ambanja mg
# bredasdorp za
# aklavik ca
# hilo us
# rikitea pf
# esperance au
# maceio br
# bambous virieux mu
# vila franca do campo pt
# gravdal no
# punta arenas cl
# esmeraldas ec
# neiafu to
# sedelnikovo ru
# saint-philippe re
# biloela au
# chokurdakh ru
# jamestown sh
# upernavik gl
# busselton au
# barrow us
# colombo lk
# zarya ru
# hobart au
# new norfolk au
# burgeo ca
# mana gf
# rikitea pf
# tuktoyaktuk ca
# sao filipe cv
# hambantota lk
# rikitea pf
# nadvoitsy ru
# hlotse ls
# mataura pf
# kamenskoye ru
# hermanus za
# dingle ie
# bolungarvik is
# kapaa us
# akureyri is
# ushuaia ar
# hobyo so
# luchegorsk ru
# lucapa ao
# ushuaia ar
# avera pf
# tasiilaq gl
# bluff nz
# masty by
# port alfred za
# porec hr
# hobart au
# simpang id
# punta arenas cl
# barrow us
# taolanaro mg
# ushuaia ar
# nikolskoye ru
# albany au
# samusu ws
# evensk ru
# barrow us
# punta arenas cl
# rikitea pf
# illoqqortoormiut gl
# hualmay pe
# victoria sc
# cape town za
# bokspits bw
# urla tr
# naze jp
# mataura pf
# araguatins br
# havre-saint-pierre ca
# kodiak us
# hamilton bm
# hasaki jp
# hamadan ir
# barrow us
# jamestown sh
# sentyabrskiy ru
# saskylakh ru
# iqaluit ca
# rikitea pf
# amderma ru
# meyungs pw
# tasiilaq gl
# qaanaaq gl
# barrow us
# sitka us
# chiknayakanhalli in
# bethlehem za
# arroio grande br
# torbay ca
# mayor pablo lagerenza py
# honiara sb
# albany au
# cidreira br
# jibuti dj
# temnikov ru
# honiara sb
# faanui pf
# ushuaia ar
# barentu er
# kaeo nz
# bluff nz
# murray bridge au
# salalah om
# pevek ru
# awbari ly
# myaundzha ru
# la peca pe
# mehamn no
# encruzilhada do sul br
# mataura pf
# beyneu kz
# bluff nz
# atuona pf
# saryozek kz
# illoqqortoormiut gl
# thompson ca
# castro cl
# cayenne gf
# albany au
# upernavik gl
# bud no
# cape town za
# castro cl
# bambous virieux mu
# kruisfontein za
# rikitea pf
# hamilton bm
# iwanai jp
# mahebourg mu
# canutama br
# albany au
# marrakesh ma
# xining cn
# tommot ru
# busselton au
# ambulu id
# mataura pf
# ponta do sol cv
# ushuaia ar
# cidreira br
# katsuura jp
# henties bay na
# mabaruma gy
# barrow us
# chuy uy
# kousseri cm
# bluff nz
# havoysund no
# pevek ru
# olafsvik is
# sao miguel do araguaia br
# lishui cn
# prince rupert ca
# ushuaia ar
# kodiak us
# buguruslan ru
# isangel vu
# sentyabrskiy ru
# tevaitoa pf
# chardara kz
# mar del plata ar
# lolua tv
# ushuaia ar
# bengkulu id
# hamilton bm
# inhambane mz
# nikolskoye ru
# mataura pf
# najran sa
# pilar ph
# rikitea pf
# kapaa us
# new norfolk au
# babino ru
# mataura pf
# khasan ru
# goderich sl
# codrington ag
# hasaki jp
# njombe tz
# tual id
# ushuaia ar
# mataura pf
# jamestown sh
# ushuaia ar
# butaritari ki
# mataura pf
# kasongo-lunda cd
# tura ru
# chokurdakh ru
# jamestown sh
# nouadhibou mr
# rikitea pf
# lebu cl
# rikitea pf
# bambous virieux mu
# ushuaia ar
# mahebourg mu
# vestmannaeyjar is
# kawalu id
# cape town za
# cherskiy ru
# dikson ru
# saint-philippe re
# lagoa pt
# saint-augustin ca
# buraydah sa
# katsuura jp
# anadyr ru
# san patricio mx
# mitsamiouli km
# norman wells ca
# busselton au
# bambous virieux mu
# sibut cf
# vaitupu wf
# rikitea pf
# oranjemund na
# rikitea pf
# punta arenas cl
# onega ru
# taolanaro mg
# busselton au
# isiro cd
# bredasdorp za
# fort nelson ca
# ponta do sol cv
# kapaa us
# albany au
# srednekolymsk ru
# khatanga ru
# grand river south east mu
# kurtamysh ru
# butaritari ki
# tiksi ru
# hithadhoo mv
# montmagny ca
# atuona pf
# bethel us
# kaitangata nz
# bethel us
# chuy uy
# amderma ru
# sampit id
# grimshaw ca
# ushuaia ar
# kahului us
# chuy uy
# hamilton bm
# ponta do sol cv
# rikitea pf
# busselton au
# ponta do sol cv
# butaritari ki
# kaitangata nz
# avarua ck
# victoria sc
# mineiros br
# butaritari ki
# sohag eg
# tazovskiy ru
# illoqqortoormiut gl
# tahe cn
# ushuaia ar
# atuona pf
# igarka ru
# barentsburg sj
# luwuk id
# dzhusaly kz
# kapaa us
# komsomolskiy ru
# alice springs au
# hilo us
# san cristobal ec
# halalo wf
# narrabri au
# hermanus za
# torbay ca
# clyde river ca
# provideniya ru
# tumannyy ru
# illoqqortoormiut gl
# hami cn
# bengkulu id
# simao cn
# illoqqortoormiut gl
# niquero cu
# kapaa us
# longonjo ao
# yellowknife ca
# rikitea pf
# illoqqortoormiut gl
# georgetown sh
# georgetown sh
# barentsburg sj
# bethanien na
# khatanga ru
# saleaula ws
# dingle ie
# butaritari ki
# hasaki jp
# tak th
# thompson ca
# kamenskoye ru
# rochegda ru
# yellowknife ca
# juifang tw
# carnarvon au
# eyl so
# qaanaaq gl
# mataura pf
# castro cl
# nanakuli us
# bethel us
# barentsburg sj
# xining cn
# pisco pe
# wanning cn
# hobart au
# zhigalovo ru
# thompson ca
# sauda no
# salina us
# luderitz na
# narsaq gl
# busselton au
# balkanabat tm
# ushuaia ar

# %%
# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=75dc0403d322ef78d90a200090a263eb&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":211,"main":"Thunderstorm","description":"thunderstorm","icon":"11d"}],"base":"stations","main":{"temp":77.32,"feels_like":78.13,"temp_min":74.14,"temp_max":80.55,"pressure":1005,"humidity":72},"visibility":10000,"wind":{"speed":17.27,"deg":210,"gust":25.32},"clouds":{"all":75},"dt":1657668627,"sys":{"type":1,"id":3486,"country":"US","sunrise":1657617491,"sunset":1657671667},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 211,
#    'main': 'Thunderstorm',
#    'description': 'thunderstorm',
#    'icon': '11d'}],
#  'base': 'stations',
#  'main': {'temp': 77.32,
#   'feels_like': 78.13,
#   'temp_min': 74.14,
#   'temp_max': 80.55,
#   'pressure': 1005,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 210, 'gust': 25.32},
#  'clouds': {'all': 75},
#  'dt': 1657668627,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1657617491,
#   'sunset': 1657671667},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 211,
#    'main': 'Thunderstorm',
#    'description': 'thunderstorm',
#    'icon': '11d'}],
#  'base': 'stations',
#  'main': {'temp': 77.32,
#   'feels_like': 78.13,
#   'temp_min': 74.14,
#   'temp_max': 80.55,
#   'pressure': 1005,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 210, 'gust': 25.32},
#  'clouds': {'all': 75},
#  'dt': 1657668627,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1657617491,
#   'sunset': 1657671667},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1657617491,
#  'sunset': 1657671667}

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 80.55 72 75 17.27

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 7, 12, 23, 30, 27)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-07-12 23:30:27'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
for i, item in enumerate(list):
# Out:
#   File "C:\Users\Jeff Mosley\AppData\Local\Temp\ipykernel_12752\1088133257.py", line 1
#     for i, item in enumerate(list):
#                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i%50== 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '07/13/22'
