# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 736

# %%
#Import dependencies
import requests
from Config import weather_api_key
#url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | borogontsy
# Processing Record 4 of Set 1 | barcelos
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | mandalgovi
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | lampazos de naranjo
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | rocha
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | sensuntepeque
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | manavalakurichi
# Processing Record 20 of Set 1 | tautira
# Processing Record 21 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | cap malheureux
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | inhambane
# Processing Record 27 of Set 1 | hami
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | baykit
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | raudeberg
# Processing Record 33 of Set 1 | bayji
# Processing Record 34 of Set 1 | fort nelson
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | fukue
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | ekhabi
# Processing Record 43 of Set 1 | paamiut
# Processing Record 44 of Set 1 | mo i rana
# Processing Record 45 of Set 1 | maniitsoq
# Processing Record 46 of Set 1 | santa cruz de tenerife
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | camacha
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | haines junction
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | muscat
# Processing Record 5 of Set 2 | taltal
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | talesh
# City not found. Skipping...
# Processing Record 9 of Set 2 | hofn
# Processing Record 10 of Set 2 | san policarpo
# Processing Record 11 of Set 2 | maningrida
# Processing Record 12 of Set 2 | burica
# City not found. Skipping...
# Processing Record 13 of Set 2 | aksu
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | saint anthony
# Processing Record 16 of Set 2 | codrington
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | zabaykalsk
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | sitka
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | urumqi
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | tamiahua
# Processing Record 28 of Set 2 | svetlogorsk
# Processing Record 29 of Set 2 | villefranche-de-rouergue
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | qujing
# Processing Record 32 of Set 2 | athabasca
# Processing Record 33 of Set 2 | carire
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 2 | gotsu
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | mount pleasant
# Processing Record 40 of Set 2 | kaseda
# Processing Record 41 of Set 2 | ust-maya
# Processing Record 42 of Set 2 | saint-georges
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | wa
# City not found. Skipping...
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | berlevag
# Processing Record 47 of Set 2 | bela
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | shar
# Processing Record 50 of Set 2 | geraldton
# Processing Record 1 of Set 3 | charters towers
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | ochamchira
# Processing Record 4 of Set 3 | batagay-alyta
# Processing Record 5 of Set 3 | puerto cabezas
# Processing Record 6 of Set 3 | hailar
# Processing Record 7 of Set 3 | krasnousolskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | alyangula
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | bujaru
# Processing Record 16 of Set 3 | bairiki
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | maragogi
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | coahuayana
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | pangkalanbuun
# Processing Record 28 of Set 3 | olovyannaya
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | nizhniy kuranakh
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | makhinjauri
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | sawankhalok
# Processing Record 39 of Set 3 | richards bay
# Processing Record 40 of Set 3 | umm lajj
# Processing Record 41 of Set 3 | asau
# Processing Record 42 of Set 3 | la rioja
# Processing Record 43 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 3 | norilsk
# Processing Record 45 of Set 3 | cap-aux-meules
# Processing Record 46 of Set 3 | kununurra
# Processing Record 47 of Set 3 | carahue
# Processing Record 48 of Set 3 | poum
# Processing Record 49 of Set 3 | umm kaddadah
# Processing Record 50 of Set 3 | isangel
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | show low
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | banda aceh
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | fayaoue
# Processing Record 7 of Set 4 | vestmannaeyjar
# Processing Record 8 of Set 4 | san joaquin
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | amapa
# Processing Record 11 of Set 4 | guryevsk
# Processing Record 12 of Set 4 | yahotyn
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | sibolga
# Processing Record 15 of Set 4 | half moon bay
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | ambilobe
# Processing Record 19 of Set 4 | bosaso
# Processing Record 20 of Set 4 | xai-xai
# Processing Record 21 of Set 4 | linfen
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | kirkwall
# Processing Record 25 of Set 4 | mehamn
# Processing Record 26 of Set 4 | jalakandapuram
# Processing Record 27 of Set 4 | necochea
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | kraslava
# Processing Record 30 of Set 4 | xinmin
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | gao
# Processing Record 33 of Set 4 | novikovo
# Processing Record 34 of Set 4 | severo-kurilsk
# Processing Record 35 of Set 4 | taoudenni
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | kamarion
# Processing Record 39 of Set 4 | auki
# Processing Record 40 of Set 4 | ramhormoz
# Processing Record 41 of Set 4 | padang
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | iquique
# Processing Record 44 of Set 4 | port alfred
# Processing Record 45 of Set 4 | madhogarh
# Processing Record 46 of Set 4 | jinchang
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | minas
# Processing Record 49 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 4 | norman wells
# Processing Record 1 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 5 | kabalo
# Processing Record 3 of Set 5 | guilin
# Processing Record 4 of Set 5 | buritis
# Processing Record 5 of Set 5 | santiago del estero
# Processing Record 6 of Set 5 | bluff
# Processing Record 7 of Set 5 | champerico
# Processing Record 8 of Set 5 | marienburg
# Processing Record 9 of Set 5 | urshelskiy
# Processing Record 10 of Set 5 | san patricio
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | bereda
# Processing Record 13 of Set 5 | rio esteban
# Processing Record 14 of Set 5 | cortes
# Processing Record 15 of Set 5 | dicabisagan
# Processing Record 16 of Set 5 | krasnoselkup
# Processing Record 17 of Set 5 | diamantino
# Processing Record 18 of Set 5 | bubaque
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | port lincoln
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | barrow
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | carnarvon
# Processing Record 26 of Set 5 | aguimes
# Processing Record 27 of Set 5 | vila franca do campo
# Processing Record 28 of Set 5 | ust-tsilma
# Processing Record 29 of Set 5 | mabaruma
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | san quintin
# Processing Record 32 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 5 | batemans bay
# Processing Record 34 of Set 5 | tenango
# Processing Record 35 of Set 5 | porto velho
# Processing Record 36 of Set 5 | sept-iles
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | valdivia
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | eyl
# Processing Record 41 of Set 5 | harper
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 5 | ouahigouya
# Processing Record 45 of Set 5 | prince rupert
# Processing Record 46 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 5 | minggang
# Processing Record 48 of Set 5 | balkanabat
# Processing Record 49 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 5 | luganville
# Processing Record 1 of Set 6 | usinsk
# Processing Record 2 of Set 6 | chowchilla
# Processing Record 3 of Set 6 | beringovskiy
# Processing Record 4 of Set 6 | manokwari
# Processing Record 5 of Set 6 | sao miguel
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | seydi
# Processing Record 9 of Set 6 | quelimane
# Processing Record 10 of Set 6 | provideniya
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | suez
# Processing Record 13 of Set 6 | palazzolo acreide
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | treinta y tres
# Processing Record 16 of Set 6 | pevek
# Processing Record 17 of Set 6 | dunedin
# Processing Record 18 of Set 6 | aranjuez
# Processing Record 19 of Set 6 | havre-saint-pierre
# Processing Record 20 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 6 | mana
# Processing Record 22 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 6 | corinto
# Processing Record 24 of Set 6 | sorland
# Processing Record 25 of Set 6 | solnechnyy
# Processing Record 26 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 6 | lakhtar
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | kavieng
# Processing Record 30 of Set 6 | kirakira
# Processing Record 31 of Set 6 | buta
# Processing Record 32 of Set 6 | kavaratti
# Processing Record 33 of Set 6 | talas
# Processing Record 34 of Set 6 | polahongon
# Processing Record 35 of Set 6 | thiruvananthapuram
# Processing Record 36 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 6 | okhotsk
# Processing Record 38 of Set 6 | hualmay
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | uray
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | nanortalik
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 6 | durham
# Processing Record 47 of Set 6 | asuncion
# Processing Record 48 of Set 6 | alugan
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | marawi
# Processing Record 1 of Set 7 | cidreira
# Processing Record 2 of Set 7 | itupeva
# Processing Record 3 of Set 7 | arauco
# Processing Record 4 of Set 7 | great bend
# Processing Record 5 of Set 7 | mwense
# Processing Record 6 of Set 7 | karratha
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | douglas
# Processing Record 9 of Set 7 | cherskiy
# Processing Record 10 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 7 | lasa
# Processing Record 12 of Set 7 | rosetta
# Processing Record 13 of Set 7 | katherine
# Processing Record 14 of Set 7 | shubarshi
# Processing Record 15 of Set 7 | panguna
# Processing Record 16 of Set 7 | vao
# Processing Record 17 of Set 7 | kuusamo
# Processing Record 18 of Set 7 | ponta delgada
# Processing Record 19 of Set 7 | hammerfest
# Processing Record 20 of Set 7 | pujili
# Processing Record 21 of Set 7 | ghatsila
# Processing Record 22 of Set 7 | takoradi
# Processing Record 23 of Set 7 | rameshki
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | meulaboh
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | bredasdorp
# Processing Record 28 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | ahipara
# Processing Record 31 of Set 7 | maldonado
# Processing Record 32 of Set 7 | aljezur
# Processing Record 33 of Set 7 | kodinsk
# Processing Record 34 of Set 7 | mitsamiouli
# Processing Record 35 of Set 7 | cockburn town
# Processing Record 36 of Set 7 | huanren
# Processing Record 37 of Set 7 | constitucion
# Processing Record 38 of Set 7 | ati
# Processing Record 39 of Set 7 | sao gabriel da cachoeira
# Processing Record 40 of Set 7 | naze
# Processing Record 41 of Set 7 | acapulco
# Processing Record 42 of Set 7 | paraiso
# Processing Record 43 of Set 7 | skjervoy
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | biltine
# Processing Record 46 of Set 7 | araouane
# Processing Record 47 of Set 7 | vredendal
# Processing Record 48 of Set 7 | kahului
# Processing Record 49 of Set 7 | moerai
# Processing Record 50 of Set 7 | moshupa
# Processing Record 1 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 8 | siniscola
# Processing Record 3 of Set 8 | kudahuvadhoo
# Processing Record 4 of Set 8 | tura
# Processing Record 5 of Set 8 | tutoia
# Processing Record 6 of Set 8 | norden
# Processing Record 7 of Set 8 | damnagar
# Processing Record 8 of Set 8 | faanui
# Processing Record 9 of Set 8 | rio gallegos
# Processing Record 10 of Set 8 | marsh harbour
# Processing Record 11 of Set 8 | maloy
# Processing Record 12 of Set 8 | kitui
# Processing Record 13 of Set 8 | tumut
# Processing Record 14 of Set 8 | itacarambi
# Processing Record 15 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 8 | lerwick
# Processing Record 17 of Set 8 | esperance
# Processing Record 18 of Set 8 | nouadhibou
# Processing Record 19 of Set 8 | tarko-sale
# Processing Record 20 of Set 8 | jaru
# Processing Record 21 of Set 8 | hay river
# Processing Record 22 of Set 8 | sola
# Processing Record 23 of Set 8 | victoria
# Processing Record 24 of Set 8 | labuan
# Processing Record 25 of Set 8 | cooma
# Processing Record 26 of Set 8 | kyrylivka
# Processing Record 27 of Set 8 | verkhnyaya khava
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | gamboma
# Processing Record 30 of Set 8 | viedma
# Processing Record 31 of Set 8 | niquero
# Processing Record 32 of Set 8 | tateyama
# Processing Record 33 of Set 8 | abnub
# Processing Record 34 of Set 8 | simpang
# Processing Record 35 of Set 8 | mount isa
# Processing Record 36 of Set 8 | dosso
# Processing Record 37 of Set 8 | kilindoni
# Processing Record 38 of Set 8 | itoman
# Processing Record 39 of Set 8 | cabo rojo
# Processing Record 40 of Set 8 | grand forks
# Processing Record 41 of Set 8 | cascais
# Processing Record 42 of Set 8 | puerto palomas
# Processing Record 43 of Set 8 | puerto colombia
# Processing Record 44 of Set 8 | adrar
# Processing Record 45 of Set 8 | grindavik
# Processing Record 46 of Set 8 | boende
# Processing Record 47 of Set 8 | bulgan
# Processing Record 48 of Set 8 | puerto escondido
# Processing Record 49 of Set 8 | tommot
# Processing Record 50 of Set 8 | repelon
# Processing Record 1 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 9 | long
# Processing Record 3 of Set 9 | peniche
# Processing Record 4 of Set 9 | laguna
# Processing Record 5 of Set 9 | bestobe
# Processing Record 6 of Set 9 | oga
# Processing Record 7 of Set 9 | byron bay
# Processing Record 8 of Set 9 | sri aman
# Processing Record 9 of Set 9 | marathopolis
# City not found. Skipping...
# Processing Record 10 of Set 9 | turayf
# Processing Record 11 of Set 9 | popondetta
# Processing Record 12 of Set 9 | colesberg
# Processing Record 13 of Set 9 | yala
# Processing Record 14 of Set 9 | bay roberts
# Processing Record 15 of Set 9 | tessalit
# Processing Record 16 of Set 9 | juneau
# Processing Record 17 of Set 9 | forio
# Processing Record 18 of Set 9 | kenai
# Processing Record 19 of Set 9 | vagamo
# Processing Record 20 of Set 9 | lodja
# Processing Record 21 of Set 9 | along
# Processing Record 22 of Set 9 | ancud
# Processing Record 23 of Set 9 | dudinka
# Processing Record 24 of Set 9 | ipanema
# Processing Record 25 of Set 9 | svetlaya
# Processing Record 26 of Set 9 | honningsvag
# Processing Record 27 of Set 9 | kumbhraj
# Processing Record 28 of Set 9 | teya
# Processing Record 29 of Set 9 | boyolangu
# Processing Record 30 of Set 9 | chifeng
# Processing Record 31 of Set 9 | skibbereen
# Processing Record 32 of Set 9 | sawtell
# Processing Record 33 of Set 9 | nettuno
# Processing Record 34 of Set 9 | hithadhoo
# Processing Record 35 of Set 9 | pocone
# Processing Record 36 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 9 | kirkland lake
# Processing Record 38 of Set 9 | mirina
# City not found. Skipping...
# Processing Record 39 of Set 9 | alba
# Processing Record 40 of Set 9 | ozinki
# Processing Record 41 of Set 9 | kiama
# Processing Record 42 of Set 9 | mindelo
# Processing Record 43 of Set 9 | angoche
# Processing Record 44 of Set 9 | burns lake
# Processing Record 45 of Set 9 | abbeville
# Processing Record 46 of Set 9 | svobodnyy
# Processing Record 47 of Set 9 | deputatskiy
# Processing Record 48 of Set 9 | mirnyy
# Processing Record 49 of Set 9 | nishihara
# Processing Record 50 of Set 9 | shimoda
# Processing Record 1 of Set 10 | kapit
# Processing Record 2 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 10 | marshall
# Processing Record 4 of Set 10 | gazanjyk
# Processing Record 5 of Set 10 | dubbo
# Processing Record 6 of Set 10 | alghero
# Processing Record 7 of Set 10 | emerald
# Processing Record 8 of Set 10 | mvuma
# Processing Record 9 of Set 10 | parfino
# Processing Record 10 of Set 10 | salou
# Processing Record 11 of Set 10 | ous
# Processing Record 12 of Set 10 | gwadar
# Processing Record 13 of Set 10 | minden
# Processing Record 14 of Set 10 | bundaberg
# Processing Record 15 of Set 10 | talnakh
# Processing Record 16 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 10 | los llanos de aridane
# Processing Record 18 of Set 10 | kyshtovka
# Processing Record 19 of Set 10 | coos bay
# Processing Record 20 of Set 10 | dubrajpur
# Processing Record 21 of Set 10 | krasnopillya
# Processing Record 22 of Set 10 | ternate
# Processing Record 23 of Set 10 | belmonte
# Processing Record 24 of Set 10 | poronaysk
# Processing Record 25 of Set 10 | keti bandar
# Processing Record 26 of Set 10 | tilichiki
# Processing Record 27 of Set 10 | iqaluit
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | bukachacha
# Processing Record 30 of Set 10 | wenling
# Processing Record 31 of Set 10 | agadez
# Processing Record 32 of Set 10 | severomuysk
# Processing Record 33 of Set 10 | port macquarie
# Processing Record 34 of Set 10 | balikpapan
# Processing Record 35 of Set 10 | kawalu
# Processing Record 36 of Set 10 | yarada
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | gisborne
# Processing Record 39 of Set 10 | quime
# Processing Record 40 of Set 10 | dakar
# Processing Record 41 of Set 10 | udgir
# Processing Record 42 of Set 10 | basco
# Processing Record 43 of Set 10 | ulaangom
# Processing Record 44 of Set 10 | sao borja
# Processing Record 45 of Set 10 | dongying
# Processing Record 46 of Set 10 | inuvik
# Processing Record 47 of Set 10 | dehloran
# Processing Record 48 of Set 10 | mount gambier
# Processing Record 49 of Set 10 | udachnyy
# Processing Record 50 of Set 10 | saint-leu
# Processing Record 1 of Set 11 | tete
# Processing Record 2 of Set 11 | yairipok
# Processing Record 3 of Set 11 | knysna
# Processing Record 4 of Set 11 | kaparellion
# Processing Record 5 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 6 of Set 11 | portland
# Processing Record 7 of Set 11 | shingu
# Processing Record 8 of Set 11 | tromso
# Processing Record 9 of Set 11 | babati
# Processing Record 10 of Set 11 | banyo
# Processing Record 11 of Set 11 | filimonovo
# Processing Record 12 of Set 11 | dhidhdhoo
# Processing Record 13 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 11 | alta floresta
# Processing Record 15 of Set 11 | xining
# Processing Record 16 of Set 11 | burnie
# Processing Record 17 of Set 11 | kangaatsiaq
# Processing Record 18 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 19 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 11 | saint-joseph
# Processing Record 21 of Set 11 | impfondo
# Processing Record 22 of Set 11 | omboue
# Processing Record 23 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 11 | mecca
# Processing Record 25 of Set 11 | deer lake
# Processing Record 26 of Set 11 | smithers
# Processing Record 27 of Set 11 | chernyshevskiy
# Processing Record 28 of Set 11 | kropotkin
# Processing Record 29 of Set 11 | katsuura
# Processing Record 30 of Set 11 | mocuba
# Processing Record 31 of Set 11 | siyabuswa
# Processing Record 32 of Set 11 | aklavik
# Processing Record 33 of Set 11 | beloha
# Processing Record 34 of Set 11 | betare oya
# Processing Record 35 of Set 11 | marrakesh
# Processing Record 36 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 37 of Set 11 | icatu
# Processing Record 38 of Set 11 | kishi
# Processing Record 39 of Set 11 | port-cartier
# Processing Record 40 of Set 11 | heihe
# Processing Record 41 of Set 11 | illela
# Processing Record 42 of Set 11 | ambo
# Processing Record 43 of Set 11 | merauke
# Processing Record 44 of Set 11 | kon tum
# Processing Record 45 of Set 11 | les cayes
# Processing Record 46 of Set 11 | auray
# Processing Record 47 of Set 11 | nazare
# Processing Record 48 of Set 11 | haimen
# Processing Record 49 of Set 11 | yangjiang
# Processing Record 50 of Set 11 | calhoun
# Processing Record 1 of Set 12 | hervey bay
# Processing Record 2 of Set 12 | beirut
# Processing Record 3 of Set 12 | joshimath
# Processing Record 4 of Set 12 | sosnovo-ozerskoye
# Processing Record 5 of Set 12 | jasper
# Processing Record 6 of Set 12 | shelbyville
# Processing Record 7 of Set 12 | armidale
# Processing Record 8 of Set 12 | plettenberg bay
# Processing Record 9 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 12 | tefe
# Processing Record 11 of Set 12 | pec
# Processing Record 12 of Set 12 | egvekinot
# Processing Record 13 of Set 12 | dalby
# Processing Record 14 of Set 12 | kletnya
# Processing Record 15 of Set 12 | tokonou
# Processing Record 16 of Set 12 | yakeshi
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | nome
# Processing Record 19 of Set 12 | opatija
# Processing Record 20 of Set 12 | niono
# Processing Record 21 of Set 12 | malibu
# Processing Record 22 of Set 12 | lahaina
# Processing Record 23 of Set 12 | yar-sale
# Processing Record 24 of Set 12 | altamont
# Processing Record 25 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 12 | kushiro
# Processing Record 28 of Set 12 | patiya
# Processing Record 29 of Set 12 | key largo
# Processing Record 30 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 12 | ardmore
# Processing Record 32 of Set 12 | pandamatenga
# Processing Record 33 of Set 12 | hasaki
# Processing Record 34 of Set 12 | mutoko
# Processing Record 35 of Set 12 | kloulklubed
# Processing Record 36 of Set 12 | ciudad guayana
# Processing Record 37 of Set 12 | el vigia
# Processing Record 38 of Set 12 | namatanai
# Processing Record 39 of Set 12 | kaohsiung
# Processing Record 40 of Set 12 | bangkalan
# Processing Record 41 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 12 | ust-ordynskiy
# Processing Record 43 of Set 12 | limbang
# Processing Record 44 of Set 12 | maciel
# Processing Record 45 of Set 12 | kontagora
# Processing Record 46 of Set 12 | saurimo
# Processing Record 47 of Set 12 | linjiang
# Processing Record 48 of Set 12 | zhuanghe
# Processing Record 49 of Set 12 | chute-aux-outardes
# Processing Record 50 of Set 12 | de-kastri
# Processing Record 1 of Set 13 | chumikan
# Processing Record 2 of Set 13 | coxim
# Processing Record 3 of Set 13 | stokmarknes
# Processing Record 4 of Set 13 | verkhoshizhemye
# Processing Record 5 of Set 13 | soderhamn
# Processing Record 6 of Set 13 | shitanjing
# Processing Record 7 of Set 13 | mwinilunga
# Processing Record 8 of Set 13 | san jose de rio tinto
# Processing Record 9 of Set 13 | te anau
# Processing Record 10 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | malakal
# Processing Record 13 of Set 13 | ngatea
# Processing Record 14 of Set 13 | leh
# Processing Record 15 of Set 13 | rybachiy
# Processing Record 16 of Set 13 | sao filipe
# Processing Record 17 of Set 13 | quesnel
# Processing Record 18 of Set 13 | vysha
# Processing Record 19 of Set 13 | tecoanapa
# Processing Record 20 of Set 13 | santa cruz
# Processing Record 21 of Set 13 | beipiao
# Processing Record 22 of Set 13 | waitati
# Processing Record 23 of Set 13 | trairi
# Processing Record 24 of Set 13 | orlik
# Processing Record 25 of Set 13 | lovozero
# Processing Record 26 of Set 13 | nianzishan
# Processing Record 27 of Set 13 | praia da vitoria
# Processing Record 28 of Set 13 | mombetsu
# Processing Record 29 of Set 13 | ascension
# Processing Record 30 of Set 13 | rundu
# Processing Record 31 of Set 13 | zhukovka
# Processing Record 32 of Set 13 | ostersund
# Processing Record 33 of Set 13 | surt
# Processing Record 34 of Set 13 | hambantota
# Processing Record 35 of Set 13 | assela
# City not found. Skipping...
# Processing Record 36 of Set 13 | evensk
# Processing Record 37 of Set 13 | los alamos
# Processing Record 38 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 13 | zhigansk
# Processing Record 40 of Set 13 | zlobin
# Processing Record 41 of Set 13 | catalina
# Processing Record 42 of Set 13 | honghu
# Processing Record 43 of Set 13 | aykhal
# Processing Record 44 of Set 13 | touros
# Processing Record 45 of Set 13 | novoilinsk
# Processing Record 46 of Set 13 | nantong
# Processing Record 47 of Set 13 | eureka
# Processing Record 48 of Set 13 | uni
# Processing Record 49 of Set 13 | plerin
# Processing Record 50 of Set 13 | nizwa
# Processing Record 1 of Set 14 | anadyr
# Processing Record 2 of Set 14 | lekoni
# Processing Record 3 of Set 14 | canavieiras
# Processing Record 4 of Set 14 | san carlos de bariloche
# Processing Record 5 of Set 14 | ostrovnoy
# Processing Record 6 of Set 14 | ladario
# Processing Record 7 of Set 14 | tomatlan
# Processing Record 8 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 14 | karasuk
# Processing Record 10 of Set 14 | scottsbluff
# Processing Record 11 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 12 of Set 14 | petauke
# Processing Record 13 of Set 14 | yaan
# Processing Record 14 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 14 | adeje
# Processing Record 16 of Set 14 | lamar
# Processing Record 17 of Set 14 | yambio
# Processing Record 18 of Set 14 | bacungan
# Processing Record 19 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | suntar
# Processing Record 22 of Set 14 | griffith
# Processing Record 23 of Set 14 | vilcun
# Processing Record 24 of Set 14 | huilong
# Processing Record 25 of Set 14 | lithakia
# Processing Record 26 of Set 14 | lalmohan
# Processing Record 27 of Set 14 | nizhniy baskunchak
# Processing Record 28 of Set 14 | shache
# Processing Record 29 of Set 14 | tambilil
# Processing Record 30 of Set 14 | komsomolskiy
# Processing Record 31 of Set 14 | bheramara
# Processing Record 32 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 33 of Set 14 | chunoyar
# Processing Record 34 of Set 14 | jiangkou
# Processing Record 35 of Set 14 | darnah
# Processing Record 36 of Set 14 | kozhva
# Processing Record 37 of Set 14 | claresholm
# Processing Record 38 of Set 14 | mapiri
# Processing Record 39 of Set 14 | tongzi
# Processing Record 40 of Set 14 | campbellsville
# Processing Record 41 of Set 14 | belyy yar
# Processing Record 42 of Set 14 | vatne
# Processing Record 43 of Set 14 | golpayegan
# Processing Record 44 of Set 14 | menongue
# Processing Record 45 of Set 14 | chara
# Processing Record 46 of Set 14 | ta khmau
# Processing Record 47 of Set 14 | maceio
# Processing Record 48 of Set 14 | shubarkuduk
# Processing Record 49 of Set 14 | oussouye
# Processing Record 50 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 1 of Set 15 | strelka
# Processing Record 2 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 15 | kaeo
# Processing Record 4 of Set 15 | lancaster
# Processing Record 5 of Set 15 | buin
# Processing Record 6 of Set 15 | galeras
# Processing Record 7 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | goderich
# Processing Record 9 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 15 | aqtobe
# Processing Record 11 of Set 15 | kholodnyy
# Processing Record 12 of Set 15 | broken hill
# Processing Record 13 of Set 15 | nara
# Processing Record 14 of Set 15 | yining
# Processing Record 15 of Set 15 | vestmanna
# Processing Record 16 of Set 15 | ndele
# Processing Record 17 of Set 15 | sinnamary
# Processing Record 18 of Set 15 | margate
# Processing Record 19 of Set 15 | biu
# Processing Record 20 of Set 15 | kolokani
# Processing Record 21 of Set 15 | sarangani
# Processing Record 22 of Set 15 | sal
# Processing Record 23 of Set 15 | pemba
# Processing Record 24 of Set 15 | konnur
# Processing Record 25 of Set 15 | port hawkesbury
# Processing Record 26 of Set 15 | buraydah
# Processing Record 27 of Set 15 | atar
# Processing Record 28 of Set 15 | ca mau
# Processing Record 29 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 15 | artyom
# Processing Record 31 of Set 15 | avera
# Processing Record 32 of Set 15 | atambua
# Processing Record 33 of Set 15 | kidal
# Processing Record 34 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 15 | huangmei
# Processing Record 36 of Set 15 | tvoroyri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 722

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Morwell      AU -38.2333  146.4000     44.40        95          89
# 1      Makasar      ID  -5.1400  119.4221     78.85        94          20
# 2     Cherskiy      RU  68.7500  161.3000     32.97        70          59
# 3      Totness      SR   5.8833  -56.3167     84.97        65           4
# 4      Te Anau      NZ -45.4167  167.7167     51.15        89          98
# 5     Chalinze      TZ  -6.6378   38.3540     75.63        50          91
# 6       Hobart      AU -42.8794  147.3294     39.06        84          40
# 7         Lebu      CL -37.6167  -73.6500     49.95        89         100
# 8        Bluff      NZ -46.6000  168.3333     51.80        66          89
# 9  New Norfolk      AU -42.7826  147.0587     38.70        83          89
#
#    Wind Speed Current Description
# 0        9.01     overcast clouds
# 1        6.91          few clouds
# 2        9.33       broken clouds
# 3        8.75           clear sky
# 4        9.46          light rain
# 5        4.56     overcast clouds
# 6       17.27    scattered clouds
# 7       13.35     overcast clouds
# 8       20.96       moderate rain
# 9        5.64     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
